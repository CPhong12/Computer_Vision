# %%
from PIL import Image

# %%
img = Image.open('Universe.jpg')

# %%
print(type(img))
print(img.format)
print(img.mode)
print(img.size)
img
# Out:
# <class 'PIL.JpegImagePlugin.JpegImageFile'>
# JPEG
# RGB
# (200, 300)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=200x300>

# %% [markdown]
# ## Resize

# %%
small_img = img.resize((200,300))
#small_img.save('small_image.png')
small_img

img.thumbnail((1200,1300))
#resize dimension (giữ x,y rút img)
#if thumbnail > image --> size of image
print(img.size)
# Out:
# (200, 300)

# %% [markdown]
# ## Crop
# img.crop(right corner coordinates, x, y)

# %%
cropped_img = img.crop((0,0, 150,150))
cropped_img
# Out:
# <PIL.Image.Image image mode=RGB size=150x150>

# %%
img2 = Image.open('C:\Code\OpenCV\DigitalSreeni\Hubble_ultra_deep_field.jpg')
print(img2.size)
# Out:
# (800, 800)

# %%
img2.thumbnail((150,200))

# %%
img_copy = img.copy()
img_copy.paste(img2, (50,50))

# %%
img_copy
# Out:
# <PIL.Image.Image image mode=RGB size=200x300>

# %% [markdown]
# ## Rotation, Flip

# %%
img90 = img.rotate(40, expand= True)
img90
# Out:
# <PIL.Image.Image image mode=RGB size=348x360>

# %%
img_flipLR = img.transpose(Image.FLIP_LEFT_RIGHT)
img_flipLR
# Out:
# <PIL.Image.Image image mode=RGB size=200x300>

# %%
img_flipTB = img.transpose(Image.FLIP_TOP_BOTTOM)
img_flipTB
# Out:
# <PIL.Image.Image image mode=RGB size=200x300>

# %% [markdown]
# ## GrayScale

# %%
gray_img = img.convert('L')
gray_img
# Out:
# <PIL.Image.Image image mode=L size=200x300>
