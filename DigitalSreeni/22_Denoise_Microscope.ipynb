# %% [markdown]
# ### Non-Local Mean

# %%
from skimage import io, img_as_float
from scipy import ndimage as nd
import matplotlib.pyplot as plt
import numpy as np
from skimage.restoration import denoise_nl_means, estimate_sigma

# %%
img=img_as_float(io.imread('Microscope.jpg'))
plt.imshow(img)

# %%
guassian_img = nd.gaussian_filter(img, sigma=2)
plt.imshow(guassian_img)

# %%
median_img = nd.median_filter(img, size=3)
plt.imshow(median_img)

# %%
sigma_est = np.mean(estimate_sigma(img))
denoise = denoise_nl_means(img, h=4.5*sigma_est, fast_mode=True, patch_size=2, patch_distance=5)

plt.imshow(denoise)
# Out:
# C:\Users\acer\AppData\Local\Temp\ipykernel_6196\4288695464.py:1: UserWarning: image is size 3 on the last axis, but channel_axis is None. If this is a color image, please set channel_axis=-1 for proper noise estimation.
#   sigma_est = np.mean(estimate_sigma(img))
